# %% [markdown]
# # Data Analysis and Data Visualization Day

# %%
# Import needed libraries 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from scipy import stats

# %%
# Read the csv file "ames_clean.csv"
path = "../csvs/"
df = pd.read_csv(path+"ames_clean.csv")
df.head()
# Out:
#   MSZoning  LotFrontage  LotArea Street     Alley LotShape LandContour  \
# 0       RL        141.0    31770   Pave  No Alley      IR1         Lvl
# 1    Other         80.0    11622   Pave  No Alley      Reg         Lvl
# 2       RL         81.0    14267   Pave  No Alley      IR1         Lvl
# 3       RL         93.0    11160   Pave  No Alley      Reg         Lvl
# 4       RL         74.0    13830   Pave  No Alley      IR1         Lvl
#
#   LotConfig LandSlope Neighborhood  ... 3SsnPorch ScreenPorch PoolArea  \
# 0    Corner       Gtl        NAmes  ...         0           0        0
# 1    Inside       Gtl        NAmes  ...         0         120        0
# 2    Corner       Gtl        NAmes  ...         0           0        0
# 3    Corner       Gtl        NAmes  ...         0           0        0
# 4    Inside       Gtl      Gilbert  ...         0           0        0
#
#     PoolQC     Fence  MiscFeature MoSold YrSold       SaleType SalePrice
# ...

# %%
# use the describe function to describe the dataset
df.describe()
# Out:
#        LotFrontage        LotArea    YearBuilt  YearRemodAdd   MasVnrArea  \
# count  2838.000000    2838.000000  2838.000000   2838.000000  2838.000000
# mean     69.227449   10070.431290  1971.235729   1984.228682    97.678295
# std      21.603608    7852.951638    29.959692     20.700583   170.217979
# min      21.000000    1300.000000  1872.000000   1950.000000     0.000000
# 25%      60.000000    7416.250000  1954.000000   1966.000000     0.000000
# 50%      70.000000    9378.500000  1973.000000   1993.000000     0.000000
# 75%      80.000000   11448.500000  2000.000000   2003.750000   161.000000
# max     313.000000  215245.000000  2010.000000   2010.000000  1600.000000
#
#         BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF  ...  \
# count  2838.000000  2838.000000  2838.000000  2838.000000  2838.000000  ...
# mean    438.120860    50.381254   557.387597  1045.889711  1153.770965  ...
# ...

# %% [markdown]
# # Now take around 10 minutes and then find out what each value means
#
# ## What does count/mean/sdt/min/25%/50%/75%/max mean?

# %%
#descriptive statistics summary
df['SalePrice'].describe()
# Out:
# count      2838.000000
# mean     178085.577872
# std       70175.787024
# min       62383.000000
# 25%      129900.000000
# 50%      160000.000000
# 75%      212000.000000
# max      455000.000000
# Name: SalePrice, dtype: float64

# %%
df.columns
# Out:
# Index(['MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape',
#        'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
# ...

# %%
print(df.shape)
# Out:
# (2838, 74)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2838 entries, 0 to 2837
# Data columns (total 74 columns):
# MSZoning         2838 non-null object
# LotFrontage      2838 non-null float64
# LotArea          2838 non-null int64
# Street           2838 non-null object
# Alley            2838 non-null object
# LotShape         2838 non-null object
# LandContour      2838 non-null object
# LotConfig        2838 non-null object
# LandSlope        2838 non-null object
# Neighborhood     2838 non-null object
# Condition1       2838 non-null object
# Condition2       2838 non-null object
# BldgType         2838 non-null object
# HouseStyle       2838 non-null object
# YearBuilt        2838 non-null int64
# YearRemodAdd     2838 non-null int64
# RoofStyle        2838 non-null object
# RoofMatl         2838 non-null object
# Exterior1st      2838 non-null object
# Exterior2nd      2838 non-null object
# MasVnrType       2838 non-null object
# MasVnrArea       2838 non-null int64
# ...

# %%
#install and Import libraries matplotib and seaborn
import matplotlib as mpl
# %matplotlib inline

# %% [markdown]
# ## Search what is histogram

# %%
#histogram
sales = df['SalePrice']
# try to change the bin numbers
sales.hist(bins=30)

# %%
#skewness and kurtosis? WHat are they?
print("Skewness: %f" % df['SalePrice'].skew())
print("Kurtosis: %f" % df['SalePrice'].kurt())
# Out:
# Skewness: 1.211370
# Kurtosis: 1.473712

# %%
#scatter plot grlivarea/saleprice
var = 'GrLivArea'
data = pd.concat([df['SalePrice'], df[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,500000));

# %%
#scatter plot number of bedrooms/saleprice 
loop = "BedroomAbvGr"
sales= 'SalePrice'
sns.lmplot(data=df, x=loop, y=sales)

# %%
df.plot.scatter(x=loop, y=sales)

# %%
sns.boxplot(x=loop, y=sales, data=df)

# %%
sns.distplot(np.array(df[sales]))

# %%
df.boxplot(column='SalePrice')

# %%
# import seaborn as sns

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-829d1bc1eccb> in <module>
#       1 nr_feats=len(df.columns)
# ----> 2 plot_corr_matrix(df, nr_feats, target)
#
# NameError: name 'plot_corr_matrix' is not defined

# %%
import matplotlib.pyplot as plt
f = plt.figure(figsize=(19, 15))
plt.matshow(df.corr())
plt.show()

# %%
#correlation matrix
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
# LotArea and Price corr
lotArea = df["LotArea"]
price = df["SalePrice"]
sns.lmplot(data=df, x="LotArea", y="SalePrice")
price.corr(lotArea)
# Out:
# 0.2490641413255881

# %% [markdown]
# With pandas and numpy libs we can find statistically significant numbers, like mean, median, mode, standard devation etc.

# %%
# lets find mean, median, std(standard devation) of SalePrice
df["SalePrice"].mean()
df["SalePrice"].median()
df["SalePrice"].std()
# Out:
# 70175.787024091

# %%
len(df.corr()['LotFrontage'])
# Out:
# 33

# %%
len(df["SalePrice"])
# Out:
# 2838

# %%
df.corr()["SalePrice"][0]
# Out:
# 0.3464137813784401

# %% [markdown]
# # Correlation table

# %%
df.corr()
# Out:
#                LotFrontage   LotArea  YearBuilt  YearRemodAdd  MasVnrArea  \
# LotFrontage       1.000000  0.397106   0.112611      0.078204    0.208225
# LotArea           0.397106  1.000000   0.012753      0.011319    0.097726
# YearBuilt         0.112611  0.012753   1.000000      0.598347    0.297713
# YearRemodAdd      0.078204  0.011319   0.598347      1.000000    0.175693
# MasVnrArea        0.208225  0.097726   0.297713      0.175693    1.000000
# BsmtFinSF1        0.200263  0.180999   0.264614      0.128600    0.265918
# BsmtFinSF2        0.051293  0.085415  -0.031150     -0.066149   -0.023363
# BsmtUnfSF         0.102633  0.015853   0.122843      0.158631    0.083177
# TotalBsmtSF       0.336579  0.240272   0.391905      0.272393    0.355349
# 1stFlrSF          0.434226  0.322935   0.290397      0.217053    0.352356
# 2ndFlrSF          0.017334  0.018624   0.002601      0.148514    0.102826
# LowQualFinSF      0.000706 -0.005359  -0.138256     -0.063752   -0.057513
# ...

# %%
sns.heatmap(df.corr(), square=True)

# %% [markdown]
# # All correllation that means something important

# %%
for j in df.corr():
    for i in range(len(df.corr()[j])):
        if df.corr()[j][i] == 1 or df.corr()[j][i] == -1:
            continue
        if df.corr()[j][i] > 0.5 or df.corr()[j][i] < -0.5:
            print(df.corr().index[i], j, df.corr()[j][i])
# Out:
# YearRemodAdd YearBuilt 0.5983468675247633
# GarageCars YearBuilt 0.5264186126828174
# SalePrice YearBuilt 0.5741541792559133
# YearBuilt YearRemodAdd 0.5983468675247633
# SalePrice YearRemodAdd 0.5429041060260018
# TotalBsmtSF BsmtFinSF1 0.5094411914276546
# BsmtFullBath BsmtFinSF1 0.634456755177271
# BsmtFinSF1 TotalBsmtSF 0.5094411914276546
# 1stFlrSF TotalBsmtSF 0.7842458817922839
# SalePrice TotalBsmtSF 0.6003880052946435
# TotalBsmtSF 1stFlrSF 0.7842458817922839
# GrLivArea 1stFlrSF 0.5353160385111204
# SalePrice 1stFlrSF 0.5896859640326391
# GrLivArea 2ndFlrSF 0.6561144224500024
# HalfBath 2ndFlrSF 0.616840185712788
# TotRmsAbvGrd 2ndFlrSF 0.580838454518661
# 1stFlrSF GrLivArea 0.5353160385111204
# 2ndFlrSF GrLivArea 0.6561144224500024
# FullBath GrLivArea 0.6187189448184411
# BedroomAbvGr GrLivArea 0.5170192915621454
# TotRmsAbvGrd GrLivArea 0.7999201913377274
# SalePrice GrLivArea 0.6776433546955144
# BsmtFinSF1 BsmtFullBath 0.634456755177271
# ...

# %% [markdown]
# As we see there no negative important correlations that statistifical means something between vars. Only positive correlational coefficents looking here.

# %% [markdown]
# # Correlation SalePrice between other
# There we list most correlated vars with SalePrice

# %%
for i in range(len(df.corr()['SalePrice'])):
    if df.corr()["SalePrice"][i] > 0.55:
        print(df.corr()["SalePrice"][i], df.corr()["SalePrice"].index[i])
# Out:
# 0.5741541792559133 YearBuilt
# 0.6003880052946435 TotalBsmtSF
# 0.5896859640326391 1stFlrSF
# 0.6776433546955144 GrLivArea
# 0.6512966334855081 GarageCars
# 0.6348218162889322 GarageArea
# 1.0 SalePrice
